# %% [markdown]
# # AFD-CNN Fall Detection on Actigraph Signals (2026-03-18)
#
# This notebook applies the **AFD-CNN** fall-detection model to four-limb Actigraph recordings
# from the **2026-03-18** session, using the activity windows defined in
# `Walking detection libraries & Actigraphs signal.ipynb` (cell 20).
#
# Pipeline overview:
# 1. Load raw 64 Hz Actigraph data for four limbs (RW, LW, RA, LA)
# 2. Compute the four-limb mean as a lumbar proxy
# 3. Use the three activity windows from the signals notebook to restrict analysis
# 4. Run **SKDH** `PredictGaitLumbarLgbm` within each window to detect walking bouts
# 5. Scan **all activity window timestamps** with a sliding AFD-CNN window
#    (200 samples @ 100 Hz = 2 s, step = 25 samples = 0.25 s)
# 6. Visualise predictions per activity and summarise fall-alert rates
#
# Source data: `/home/ubuntu/git/gait_analysis/Walkin Actigraphs tests/`
# AFD-CNN model: `/home/ubuntu/git/FD-CNN/model/model.ckpt`

# %% [markdown]
# ## 0. Setup: imports

# %%
from pathlib import Path
import sys
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from math import gcd
from scipy.signal import resample_poly

# scikit-digital-health (pre-installed in the fd-cnn venv)
import skdh
from skdh.context import PredictGaitLumbarLgbm

print('skdh version:', skdh.__version__)
print('numpy version:', np.__version__)
# Out:
# skdh version: 0.17.9
# numpy version: 2.4.4

# %% [markdown]
# ## 1. Load Actigraph data — 2026-03-18 session

# %%
BASE_DIR = Path('/home/ubuntu/git/gait_analysis/Walkin Actigraphs tests')

def load_acti_data(base_dir, fname):
    """
    Load a raw Actigraph CSV file and return a clean DataFrame.

    - Skips '#'-prefixed metadata header lines.
    - Computes vector magnitude (acc_magnitude) from all accelerometer axes.
    - Aliases axes as 'x', 'y', 'z'.
    - Parses 'Timestamp UTC' to timezone-aware datetime.
    - Builds 'seconds_elapsed' from t0=0; adds sub-second correction at 64 Hz.
    """
    df = pd.read_csv(base_dir / fname, comment='#', skip_blank_lines=True)
    df.columns = [c.strip() for c in df.columns]

    df['acc_magnitude'] = np.sqrt((df.iloc[:, 2:] ** 2).sum(axis=1))
    df['x'] = df['Accelerometer X']
    df['y'] = df['Accelerometer Y']
    df['z'] = df['Accelerometer Z']

    df['Timestamp UTC'] = pd.to_datetime(df['Timestamp UTC'], utc=True, errors='coerce')

    t0 = df['Timestamp UTC'].dropna().iloc[0]
    df['seconds_elapsed'] = (df['Timestamp UTC'] - t0).dt.total_seconds().astype(float)

    # Sub-second correction: file timestamps are per-second; reconstruct intra-second
    # position from sample index modulo 64 (sampling rate = 64 Hz).
    sec_correction = np.arange(len(df)) % 64 / 64.0
    df['seconds_elapsed'] += sec_correction
    df['Timestamp UTC'] += pd.to_timedelta(sec_correction, unit='s')

    return df


# Load all four limbs for the 2026-03-18 session
df_RW = load_acti_data(BASE_DIR, 'EALS-DATA-004_STM2D48232042_2026-03-18_12_00_00_AM_1.CSV')
df_LW = load_acti_data(BASE_DIR, 'EALS-DATA-002_STM2D48230423_2026-03-18_05_46_04_PM_1.CSV')
df_RA = load_acti_data(BASE_DIR, 'EALS-DATA-001_STM2D48230106_2026-03-18_05_46_02_PM_1.CSV')
df_LA = load_acti_data(BASE_DIR, 'EALS-DATA-003_STM2D48232727_2026-03-18_05_45_58_PM_1.CSV')

for lbl, df in [('RW', df_RW), ('LW', df_LW), ('RA', df_RA), ('LA', df_LA)]:
    print(f'{lbl}: {len(df):,} samples | '
          f'{df["Timestamp UTC"].iloc[0]} \u2192 {df["Timestamp UTC"].iloc[-1]}')
# Out:
# RW: 7,643,264 samples | 2026-03-18 00:00:00+00:00 → 2026-03-19 13:07:59.984375+00:00
# LW: 4,440,512 samples | 2026-03-18 17:46:05+00:00 → 2026-03-19 13:06:28.984375+00:00
# RA: 4,404,096 samples | 2026-03-18 17:46:03+00:00 → 2026-03-19 12:56:09.984375+00:00
# LA: 4,433,216 samples | 2026-03-18 17:45:59+00:00 → 2026-03-19 13:04:19.984375+00:00

# %% [markdown]
# ## 2. Activity windows (from signals notebook cell 20)

# %%
# Activity windows from Walking detection libraries & Actigraphs signal.ipynb (cell 20)
# Three broad activity windows from the 2026-03-18 session
classification_windows_2026_03_18 = [
    ['2026-03-18 20:20:00', '2026-03-18 21:00:00'],  # Evening walk
    ['2026-03-18 21:10:00', '2026-03-18 21:40:00'],  # Bicycle
    ['2026-03-18 23:00:00', '2026-03-19 00:10:00'],  # Daily walking
]

classification_tasks_2026_03_18 = [
    'Evening walk',
    'Bicycle',
    'Daily walking',
]

# Build tidy interval DataFrame
task_intervals = pd.DataFrame({
    'start_time': [pd.Timestamp(w[0], tz='UTC') for w in classification_windows_2026_03_18],
    'end_time':   [pd.Timestamp(w[1], tz='UTC') for w in classification_windows_2026_03_18],
    'task':       classification_tasks_2026_03_18,
})

SESSION_START = task_intervals['start_time'].min()
SESSION_END   = task_intervals['end_time'].max()

print(f'Session span: {SESSION_START} \u2192 {SESSION_END}')
print(f'Total activity windows: {len(task_intervals)}')
print(task_intervals[['task', 'start_time', 'end_time']].to_string(index=False))
# Out:
# Session span: 2026-03-18 20:20:00+00:00 → 2026-03-19 00:10:00+00:00
# Total activity windows: 3
#          task                start_time                  end_time
#  Evening walk 2026-03-18 20:20:00+00:00 2026-03-18 21:00:00+00:00
#       Bicycle 2026-03-18 21:10:00+00:00 2026-03-18 21:40:00+00:00
# Daily walking 2026-03-18 23:00:00+00:00 2026-03-19 00:10:00+00:00

# %% [markdown]
# ## 3. Four-limb mean (lumbar proxy)

# %%
# Average X, Y, Z and acc_magnitude across all four limbs on the shared timestamp grid.
# PredictGaitLumbarLgbm is trained on lumbar-mounted accelerometers; the four-limb mean
# provides a whole-body motion proxy that reduces limb-specific artefacts.

_dfs = {'RW': df_RW, 'LW': df_LW, 'RA': df_RA, 'LA': df_LA}
df_mean = df_RW[['Timestamp UTC']].copy()
for lbl, df in _dfs.items():
    df_mean = df_mean.merge(
        df[['Timestamp UTC', 'acc_magnitude', 'x', 'y', 'z']].rename(columns={
            'acc_magnitude': f'acc_magnitude_{lbl}',
            'x': f'x_{lbl}', 'y': f'y_{lbl}', 'z': f'z_{lbl}',
        }),
        on='Timestamp UTC',
        how='inner',
    )

for col in ['acc_magnitude', 'x', 'y', 'z']:
    df_mean[col] = df_mean[[f'{col}_{lbl}' for lbl in _dfs]].mean(axis=1)

print(f'Four-limb mean: {len(df_mean):,} shared samples')
print(f'Time range: {df_mean["Timestamp UTC"].iloc[0]} \u2192 {df_mean["Timestamp UTC"].iloc[-1]}')
# Out:
# Four-limb mean: 4,165,312 shared samples
# Time range: 2026-03-18 18:37:24+00:00 → 2026-03-19 12:56:09.984375+00:00

# %% [markdown]
# ## 4. Overview plot — acc_magnitude with activity backgrounds

# %%
# Colour palette — one colour per unique task
_unique_tasks = list(dict.fromkeys(classification_tasks_2026_03_18))
_palette = list(plt.cm.tab20.colors)
TASK_COLORS = {t: _palette[i % len(_palette)] for i, t in enumerate(_unique_tasks)}

def plot_session_overview(signals_dict, task_intervals, session_start, session_end, title=''):
    """Plot acc_magnitude for each signal with activity-coloured background bands."""
    fig, axes = plt.subplots(len(signals_dict), 1,
                              figsize=(26, 3 * len(signals_dict)), sharex=True)
    if len(signals_dict) == 1:
        axes = [axes]

    for ax, (label, df) in zip(axes, signals_dict.items()):
        plot_df = df[['Timestamp UTC', 'acc_magnitude']].dropna().copy()
        plot_df = plot_df[
            (plot_df['Timestamp UTC'] >= session_start) &
            (plot_df['Timestamp UTC'] <= session_end)
        ].copy()
        if plot_df.empty:
            ax.set_title(f'{label} \u2014 no data')
            continue

        t_ref = plot_df['Timestamp UTC'].iloc[0]
        plot_df['min_elapsed'] = (plot_df['Timestamp UTC'] - t_ref).dt.total_seconds() / 60.0

        for _, row in task_intervals.iterrows():
            s = (row['start_time'] - t_ref).total_seconds() / 60.0
            e = (row['end_time']   - t_ref).total_seconds() / 60.0
            ax.axvspan(s, e, color=TASK_COLORS.get(row['task'], '#cccccc'), alpha=0.35, linewidth=0)
            ax.text((s + e) / 2, 1.0, row['task'],
                    transform=ax.get_xaxis_transform(),
                    ha='center', va='top', fontsize=7, clip_on=True)

        if len(plot_df) > 50_000:
            stride = max(1, len(plot_df) // 50_000)
            plot_df = plot_df.iloc[::stride].copy()

        ax.plot(plot_df['min_elapsed'], plot_df['acc_magnitude'], color='black', lw=0.6)
        ax.axhline(0, color='0.5', ls='--', lw=0.6)
        ax.set_ylabel(f'{label}\nacc_mag (g)', fontsize=9)

    legend_handles = [
        mpatches.Patch(facecolor=TASK_COLORS[t], edgecolor='none', alpha=0.5, label=t)
        for t in _unique_tasks
    ]
    axes[0].legend(handles=legend_handles, loc='upper right', fontsize=8, ncol=3)
    axes[-1].set_xlabel('Minutes elapsed from session start')
    fig.suptitle(title, fontsize=13)
    plt.tight_layout()
    plt.show()


all_signals = {'RW': df_RW, 'LW': df_LW, 'RA': df_RA, 'LA': df_LA, 'Mean': df_mean}
plot_session_overview(
    all_signals, task_intervals, SESSION_START, SESSION_END,
    title='acc_magnitude \u2014 2026-03-18 session with activity windows',
)

# %% [markdown]
# ## 5. SKDH gait detection on the full activity window span

# %%
FS_ACTI = 64  # Actigraph sampling rate (Hz)


def resolve_time_window(time_window):
    """Convert [t0, tf] strings or Timestamps to UTC-aware pd.Timestamps."""
    if time_window is None:
        return None, None
    t0 = time_window[0] if isinstance(time_window[0], pd.Timestamp) else pd.Timestamp(time_window[0], tz='UTC')
    tf = time_window[1] if isinstance(time_window[1], pd.Timestamp) else pd.Timestamp(time_window[1], tz='UTC')
    return t0, tf


def run_skdh_on_window(df_signal, t0, tf, fs=FS_ACTI):
    """
    Run PredictGaitLumbarLgbm on a time slice of df_signal.

    Returns
    -------
    plot_df : filtered DataFrame slice used for plotting
    result  : raw dict with 'Gait Bout Start' / 'Gait Bout Stop' (Unix seconds)
    """
    plot_df = df_signal[['Timestamp UTC', 'x', 'y', 'z']].dropna().copy()
    plot_df = plot_df[
        (plot_df['Timestamp UTC'] >= t0) & (plot_df['Timestamp UTC'] <= tf)
    ].copy()
    if plot_df.empty:
        return plot_df, {'Gait Bout Start': np.array([]), 'Gait Bout Stop': np.array([])}

    time_s = plot_df['Timestamp UTC'].astype('int64').to_numpy() / 1e9
    accel  = plot_df[['x', 'y', 'z']].to_numpy(dtype=float)
    result = PredictGaitLumbarLgbm().predict(time=time_s, accel=accel, fs=fs)
    return plot_df, result


def skdh_result_to_intervals(plot_df, result):
    """Convert SKDH bout boundaries to a tidy interval DataFrame (prediction 0/1)."""
    plot_start = plot_df['Timestamp UTC'].iloc[0]
    plot_end   = plot_df['Timestamp UTC'].iloc[-1]

    gait_starts = pd.to_datetime(result['Gait Bout Start'], unit='s', utc=True)
    gait_stops  = pd.to_datetime(result['Gait Bout Stop'],  unit='s', utc=True)

    intervals, current = [], plot_start
    for bout_start, bout_stop in zip(gait_starts, gait_stops):
        bout_start = max(bout_start, plot_start)
        bout_stop  = min(bout_stop,  plot_end)
        if bout_start > current:
            intervals.append({'start_time': current,     'end_time': bout_start, 'prediction': 0})
        if bout_stop > bout_start:
            intervals.append({'start_time': bout_start,  'end_time': bout_stop,  'prediction': 1})
        current = max(current, bout_stop)
    if current < plot_end:
        intervals.append({'start_time': current, 'end_time': plot_end, 'prediction': 0})
    if not intervals:
        intervals.append({'start_time': plot_start, 'end_time': plot_end, 'prediction': 0})

    return pd.DataFrame(intervals)


# Run SKDH over the entire activity window span (using the four-limb mean as lumbar proxy)
print('Running SKDH PredictGaitLumbarLgbm over the full activity span \u2026')
plot_df_skdh, skdh_result_session = run_skdh_on_window(
    df_mean, SESSION_START, SESSION_END
)
skdh_intervals_session = skdh_result_to_intervals(plot_df_skdh, skdh_result_session)

n_bouts = len(skdh_result_session.get('Gait Bout Start', []))
print(f'SKDH detected {n_bouts} gait bout(s) over the full span')
if n_bouts:
    for i, (s, e) in enumerate(zip(
        pd.to_datetime(skdh_result_session['Gait Bout Start'], unit='s', utc=True),
        pd.to_datetime(skdh_result_session['Gait Bout Stop'],  unit='s', utc=True),
    )):
        dur = (e - s).total_seconds()
        print(f'  Bout {i+1}: {s} \u2192 {e}  ({dur:.0f} s)')
# Out:
# Running SKDH PredictGaitLumbarLgbm over the full activity span …
# SKDH detected 211 gait bout(s) over the full span
#   Bout 1: 2026-03-18 20:30:09+00:00 → 2026-03-18 20:30:12+00:00  (3 s)
#   Bout 2: 2026-03-18 20:31:12+00:00 → 2026-03-18 20:31:15+00:00  (3 s)
#   Bout 3: 2026-03-18 20:31:30+00:00 → 2026-03-18 20:31:54+00:00  (24 s)
#   Bout 4: 2026-03-18 20:32:03+00:00 → 2026-03-18 20:32:21+00:00  (18 s)
#   Bout 5: 2026-03-18 20:32:24+00:00 → 2026-03-18 20:32:27+00:00  (3 s)
#   Bout 6: 2026-03-18 20:32:36+00:00 → 2026-03-18 20:33:45+00:00  (69 s)
#   Bout 7: 2026-03-18 20:33:54+00:00 → 2026-03-18 20:34:00+00:00  (6 s)
#   Bout 8: 2026-03-18 20:34:03+00:00 → 2026-03-18 20:35:33+00:00  (90 s)
#   Bout 9: 2026-03-18 20:35:36+00:00 → 2026-03-18 20:35:39+00:00  (3 s)
#   Bout 10: 2026-03-18 20:35:48+00:00 → 2026-03-18 20:37:12+00:00  (84 s)
#   Bout 11: 2026-03-18 20:37:21+00:00 → 2026-03-18 20:37:27+00:00  (6 s)
#   Bout 12: 2026-03-18 20:37:30+00:00 → 2026-03-18 20:38:18+00:00  (48 s)
#   Bout 13: 2026-03-18 20:38:24+00:00 → 2026-03-18 20:38:45+00:00  (21 s)
#   Bout 14: 2026-03-18 20:38:51+00:00 → 2026-03-18 20:39:00+00:00  (9 s)
#   Bout 15: 2026-03-18 20:39:03+00:00 → 2026-03-18 20:40:03+00:00  (60 s)
#   Bout 16: 2026-03-18 20:40:06+00:00 → 2026-03-18 20:45:06+00:00  (300 s)
#   Bout 17: 2026-03-18 20:45:12+00:00 → 2026-03-18 20:45:15+00:00  (3 s)
#   Bout 18: 2026-03-18 20:45:36+00:00 → 2026-03-18 20:45:39+00:00  (3 s)
#   Bout 19: 2026-03-18 20:46:03+00:00 → 2026-03-18 20:46:06+00:00  (3 s)
#   Bout 20: 2026-03-18 21:11:33+00:00 → 2026-03-18 21:11:36+00:00  (3 s)
#   Bout 21: 2026-03-18 21:14:54+00:00 → 2026-03-18 21:14:57+00:00  (3 s)
#   Bout 22: 2026-03-18 21:15:42+00:00 → 2026-03-18 21:15:45+00:00  (3 s)
#   Bout 23: 2026-03-18 21:16:33+00:00 → 2026-03-18 21:16:36+00:00  (3 s)
#   Bout 24: 2026-03-18 21:17:48+00:00 → 2026-03-18 21:17:51+00:00  (3 s)
#   Bout 25: 2026-03-18 21:22:00+00:00 → 2026-03-18 21:22:03+00:00  (3 s)
#   Bout 26: 2026-03-18 21:22:27+00:00 → 2026-03-18 21:22:30+00:00  (3 s)
#   Bout 27: 2026-03-18 21:25:36+00:00 → 2026-03-18 21:25:39+00:00  (3 s)
#   Bout 28: 2026-03-18 21:30:06+00:00 → 2026-03-18 21:30:09+00:00  (3 s)
#   Bout 29: 2026-03-18 23:15:09+00:00 → 2026-03-18 23:15:12+00:00  (3 s)
#   Bout 30: 2026-03-18 23:15:18+00:00 → 2026-03-18 23:15:27+00:00  (9 s)
#   Bout 31: 2026-03-18 23:15:42+00:00 → 2026-03-18 23:15:45+00:00  (3 s)
#   Bout 32: 2026-03-18 23:15:48+00:00 → 2026-03-18 23:15:54+00:00  (6 s)
#   Bout 33: 2026-03-18 23:16:09+00:00 → 2026-03-18 23:16:21+00:00  (12 s)
#   Bout 34: 2026-03-18 23:16:27+00:00 → 2026-03-18 23:16:33+00:00  (6 s)
#   Bout 35: 2026-03-18 23:16:36+00:00 → 2026-03-18 23:16:45+00:00  (9 s)
#   Bout 36: 2026-03-18 23:16:48+00:00 → 2026-03-18 23:17:00+00:00  (12 s)
#   Bout 37: 2026-03-18 23:17:06+00:00 → 2026-03-18 23:17:15+00:00  (9 s)
#   Bout 38: 2026-03-18 23:17:18+00:00 → 2026-03-18 23:17:24+00:00  (6 s)
#   Bout 39: 2026-03-18 23:17:27+00:00 → 2026-03-18 23:17:30+00:00  (3 s)
#   Bout 40: 2026-03-18 23:17:39+00:00 → 2026-03-18 23:17:42+00:00  (3 s)
#   Bout 41: 2026-03-18 23:17:45+00:00 → 2026-03-18 23:17:57+00:00  (12 s)
#   Bout 42: 2026-03-18 23:18:03+00:00 → 2026-03-18 23:18:06+00:00  (3 s)
#   Bout 43: 2026-03-18 23:18:09+00:00 → 2026-03-18 23:18:12+00:00  (3 s)
#   Bout 44: 2026-03-18 23:18:33+00:00 → 2026-03-18 23:18:39+00:00  (6 s)
#   Bout 45: 2026-03-18 23:18:42+00:00 → 2026-03-18 23:18:48+00:00  (6 s)
#   Bout 46: 2026-03-18 23:18:51+00:00 → 2026-03-18 23:18:54+00:00  (3 s)
#   Bout 47: 2026-03-18 23:19:03+00:00 → 2026-03-18 23:19:12+00:00  (9 s)
#   Bout 48: 2026-03-18 23:19:15+00:00 → 2026-03-18 23:19:33+00:00  (18 s)
#   Bout 49: 2026-03-18 23:19:36+00:00 → 2026-03-18 23:19:42+00:00  (6 s)
#   Bout 50: 2026-03-18 23:19:45+00:00 → 2026-03-18 23:19:48+00:00  (3 s)
#   Bout 51: 2026-03-18 23:19:57+00:00 → 2026-03-18 23:20:03+00:00  (6 s)
#   Bout 52: 2026-03-18 23:20:09+00:00 → 2026-03-18 23:20:12+00:00  (3 s)
#   Bout 53: 2026-03-18 23:20:30+00:00 → 2026-03-18 23:20:33+00:00  (3 s)
#   Bout 54: 2026-03-18 23:20:57+00:00 → 2026-03-18 23:21:00+00:00  (3 s)
#   Bout 55: 2026-03-18 23:21:21+00:00 → 2026-03-18 23:21:24+00:00  (3 s)
#   Bout 56: 2026-03-18 23:21:30+00:00 → 2026-03-18 23:21:33+00:00  (3 s)
#   Bout 57: 2026-03-18 23:21:57+00:00 → 2026-03-18 23:22:00+00:00  (3 s)
#   Bout 58: 2026-03-18 23:22:03+00:00 → 2026-03-18 23:22:12+00:00  (9 s)
#   Bout 59: 2026-03-18 23:22:15+00:00 → 2026-03-18 23:22:24+00:00  (9 s)
#   Bout 60: 2026-03-18 23:22:27+00:00 → 2026-03-18 23:22:33+00:00  (6 s)
#   Bout 61: 2026-03-18 23:22:39+00:00 → 2026-03-18 23:22:42+00:00  (3 s)
#   Bout 62: 2026-03-18 23:22:45+00:00 → 2026-03-18 23:22:54+00:00  (9 s)
#   Bout 63: 2026-03-18 23:23:09+00:00 → 2026-03-18 23:23:12+00:00  (3 s)
#   Bout 64: 2026-03-18 23:23:27+00:00 → 2026-03-18 23:23:33+00:00  (6 s)
#   Bout 65: 2026-03-18 23:23:36+00:00 → 2026-03-18 23:23:45+00:00  (9 s)
#   Bout 66: 2026-03-18 23:23:57+00:00 → 2026-03-18 23:24:06+00:00  (9 s)
#   Bout 67: 2026-03-18 23:24:09+00:00 → 2026-03-18 23:24:54+00:00  (45 s)
#   Bout 68: 2026-03-18 23:25:15+00:00 → 2026-03-18 23:25:21+00:00  (6 s)
#   Bout 69: 2026-03-18 23:25:24+00:00 → 2026-03-18 23:25:57+00:00  (33 s)
#   Bout 70: 2026-03-18 23:26:00+00:00 → 2026-03-18 23:26:51+00:00  (51 s)
#   Bout 71: 2026-03-18 23:27:30+00:00 → 2026-03-18 23:27:54+00:00  (24 s)
#   Bout 72: 2026-03-18 23:28:00+00:00 → 2026-03-18 23:28:06+00:00  (6 s)
#   Bout 73: 2026-03-18 23:28:15+00:00 → 2026-03-18 23:28:54+00:00  (39 s)
#   Bout 74: 2026-03-18 23:28:57+00:00 → 2026-03-18 23:29:03+00:00  (6 s)
#   Bout 75: 2026-03-18 23:29:09+00:00 → 2026-03-18 23:29:36+00:00  (27 s)
#   Bout 76: 2026-03-18 23:29:39+00:00 → 2026-03-18 23:29:54+00:00  (15 s)
#   Bout 77: 2026-03-18 23:29:57+00:00 → 2026-03-18 23:30:03+00:00  (6 s)
#   Bout 78: 2026-03-18 23:30:12+00:00 → 2026-03-18 23:30:15+00:00  (3 s)
#   Bout 79: 2026-03-18 23:30:24+00:00 → 2026-03-18 23:30:30+00:00  (6 s)
#   Bout 80: 2026-03-18 23:30:57+00:00 → 2026-03-18 23:31:00+00:00  (3 s)
#   Bout 81: 2026-03-18 23:31:03+00:00 → 2026-03-18 23:31:09+00:00  (6 s)
#   Bout 82: 2026-03-18 23:31:12+00:00 → 2026-03-18 23:31:21+00:00  (9 s)
#   Bout 83: 2026-03-18 23:31:27+00:00 → 2026-03-18 23:31:39+00:00  (12 s)
#   Bout 84: 2026-03-18 23:31:57+00:00 → 2026-03-18 23:32:00+00:00  (3 s)
#   Bout 85: 2026-03-18 23:32:06+00:00 → 2026-03-18 23:32:12+00:00  (6 s)
#   Bout 86: 2026-03-18 23:32:24+00:00 → 2026-03-18 23:32:27+00:00  (3 s)
#   Bout 87: 2026-03-18 23:33:03+00:00 → 2026-03-18 23:33:09+00:00  (6 s)
#   Bout 88: 2026-03-18 23:33:12+00:00 → 2026-03-18 23:33:18+00:00  (6 s)
#   Bout 89: 2026-03-18 23:33:21+00:00 → 2026-03-18 23:33:27+00:00  (6 s)
#   Bout 90: 2026-03-18 23:33:30+00:00 → 2026-03-18 23:33:33+00:00  (3 s)
#   Bout 91: 2026-03-18 23:33:36+00:00 → 2026-03-18 23:33:39+00:00  (3 s)
#   Bout 92: 2026-03-18 23:33:42+00:00 → 2026-03-18 23:33:45+00:00  (3 s)
#   Bout 93: 2026-03-18 23:33:51+00:00 → 2026-03-18 23:33:57+00:00  (6 s)
#   Bout 94: 2026-03-18 23:34:12+00:00 → 2026-03-18 23:34:15+00:00  (3 s)
#   Bout 95: 2026-03-18 23:34:21+00:00 → 2026-03-18 23:34:27+00:00  (6 s)
#   Bout 96: 2026-03-18 23:34:33+00:00 → 2026-03-18 23:34:36+00:00  (3 s)
#   Bout 97: 2026-03-18 23:34:42+00:00 → 2026-03-18 23:34:45+00:00  (3 s)
#   Bout 98: 2026-03-18 23:34:48+00:00 → 2026-03-18 23:34:54+00:00  (6 s)
#   Bout 99: 2026-03-18 23:35:06+00:00 → 2026-03-18 23:35:12+00:00  (6 s)
#   Bout 100: 2026-03-18 23:35:15+00:00 → 2026-03-18 23:35:18+00:00  (3 s)
#   Bout 101: 2026-03-18 23:35:21+00:00 → 2026-03-18 23:35:30+00:00  (9 s)
#   Bout 102: 2026-03-18 23:35:45+00:00 → 2026-03-18 23:35:48+00:00  (3 s)
#   Bout 103: 2026-03-18 23:36:06+00:00 → 2026-03-18 23:36:09+00:00  (3 s)
#   Bout 104: 2026-03-18 23:36:33+00:00 → 2026-03-18 23:36:36+00:00  (3 s)
#   Bout 105: 2026-03-18 23:36:39+00:00 → 2026-03-18 23:36:42+00:00  (3 s)
#   Bout 106: 2026-03-18 23:36:48+00:00 → 2026-03-18 23:36:57+00:00  (9 s)
#   Bout 107: 2026-03-18 23:37:00+00:00 → 2026-03-18 23:37:06+00:00  (6 s)
#   Bout 108: 2026-03-18 23:37:09+00:00 → 2026-03-18 23:37:12+00:00  (3 s)
#   Bout 109: 2026-03-18 23:37:15+00:00 → 2026-03-18 23:37:18+00:00  (3 s)
#   Bout 110: 2026-03-18 23:38:42+00:00 → 2026-03-18 23:39:00+00:00  (18 s)
#   Bout 111: 2026-03-18 23:39:03+00:00 → 2026-03-18 23:39:06+00:00  (3 s)
#   Bout 112: 2026-03-18 23:39:09+00:00 → 2026-03-18 23:39:21+00:00  (12 s)
#   Bout 113: 2026-03-18 23:39:27+00:00 → 2026-03-18 23:39:39+00:00  (12 s)
#   Bout 114: 2026-03-18 23:39:48+00:00 → 2026-03-18 23:40:00+00:00  (12 s)
#   Bout 115: 2026-03-18 23:40:03+00:00 → 2026-03-18 23:40:06+00:00  (3 s)
#   Bout 116: 2026-03-18 23:40:12+00:00 → 2026-03-18 23:40:15+00:00  (3 s)
#   Bout 117: 2026-03-18 23:40:21+00:00 → 2026-03-18 23:40:27+00:00  (6 s)
#   Bout 118: 2026-03-18 23:40:30+00:00 → 2026-03-18 23:40:36+00:00  (6 s)
#   Bout 119: 2026-03-18 23:40:39+00:00 → 2026-03-18 23:40:42+00:00  (3 s)
#   Bout 120: 2026-03-18 23:40:45+00:00 → 2026-03-18 23:40:51+00:00  (6 s)
#   Bout 121: 2026-03-18 23:40:54+00:00 → 2026-03-18 23:40:57+00:00  (3 s)
#   Bout 122: 2026-03-18 23:41:09+00:00 → 2026-03-18 23:41:12+00:00  (3 s)
#   Bout 123: 2026-03-18 23:41:18+00:00 → 2026-03-18 23:41:27+00:00  (9 s)
#   Bout 124: 2026-03-18 23:41:33+00:00 → 2026-03-18 23:41:36+00:00  (3 s)
#   Bout 125: 2026-03-18 23:41:42+00:00 → 2026-03-18 23:42:09+00:00  (27 s)
#   Bout 126: 2026-03-18 23:42:12+00:00 → 2026-03-18 23:42:15+00:00  (3 s)
#   Bout 127: 2026-03-18 23:42:21+00:00 → 2026-03-18 23:42:24+00:00  (3 s)
#   Bout 128: 2026-03-18 23:42:30+00:00 → 2026-03-18 23:42:33+00:00  (3 s)
#   Bout 129: 2026-03-18 23:42:36+00:00 → 2026-03-18 23:43:00+00:00  (24 s)
#   Bout 130: 2026-03-18 23:43:06+00:00 → 2026-03-18 23:43:12+00:00  (6 s)
#   Bout 131: 2026-03-18 23:43:15+00:00 → 2026-03-18 23:43:18+00:00  (3 s)
#   Bout 132: 2026-03-18 23:43:24+00:00 → 2026-03-18 23:43:27+00:00  (3 s)
#   Bout 133: 2026-03-18 23:43:36+00:00 → 2026-03-18 23:43:39+00:00  (3 s)
#   Bout 134: 2026-03-18 23:43:42+00:00 → 2026-03-18 23:43:51+00:00  (9 s)
#   Bout 135: 2026-03-18 23:44:09+00:00 → 2026-03-18 23:44:12+00:00  (3 s)
#   Bout 136: 2026-03-18 23:44:15+00:00 → 2026-03-18 23:44:24+00:00  (9 s)
#   Bout 137: 2026-03-18 23:44:30+00:00 → 2026-03-18 23:44:33+00:00  (3 s)
#   Bout 138: 2026-03-18 23:44:36+00:00 → 2026-03-18 23:44:39+00:00  (3 s)
#   Bout 139: 2026-03-18 23:44:42+00:00 → 2026-03-18 23:44:48+00:00  (6 s)
#   Bout 140: 2026-03-18 23:44:51+00:00 → 2026-03-18 23:44:54+00:00  (3 s)
#   Bout 141: 2026-03-18 23:45:00+00:00 → 2026-03-18 23:45:03+00:00  (3 s)
#   Bout 142: 2026-03-18 23:45:09+00:00 → 2026-03-18 23:45:12+00:00  (3 s)
#   Bout 143: 2026-03-18 23:45:18+00:00 → 2026-03-18 23:45:21+00:00  (3 s)
#   Bout 144: 2026-03-18 23:45:30+00:00 → 2026-03-18 23:45:51+00:00  (21 s)
#   Bout 145: 2026-03-18 23:46:03+00:00 → 2026-03-18 23:46:06+00:00  (3 s)
#   Bout 146: 2026-03-18 23:46:09+00:00 → 2026-03-18 23:46:12+00:00  (3 s)
#   Bout 147: 2026-03-18 23:46:15+00:00 → 2026-03-18 23:46:24+00:00  (9 s)
#   Bout 148: 2026-03-18 23:46:27+00:00 → 2026-03-18 23:46:33+00:00  (6 s)
#   Bout 149: 2026-03-18 23:46:36+00:00 → 2026-03-18 23:46:45+00:00  (9 s)
#   Bout 150: 2026-03-18 23:46:48+00:00 → 2026-03-18 23:46:54+00:00  (6 s)
#   Bout 151: 2026-03-18 23:46:57+00:00 → 2026-03-18 23:47:15+00:00  (18 s)
#   Bout 152: 2026-03-18 23:47:21+00:00 → 2026-03-18 23:47:36+00:00  (15 s)
#   Bout 153: 2026-03-18 23:47:39+00:00 → 2026-03-18 23:47:42+00:00  (3 s)
#   Bout 154: 2026-03-18 23:47:48+00:00 → 2026-03-18 23:48:30+00:00  (42 s)
#   Bout 155: 2026-03-18 23:48:33+00:00 → 2026-03-18 23:48:57+00:00  (24 s)
#   Bout 156: 2026-03-18 23:49:03+00:00 → 2026-03-18 23:49:06+00:00  (3 s)
#   Bout 157: 2026-03-18 23:49:12+00:00 → 2026-03-18 23:49:18+00:00  (6 s)
#   Bout 158: 2026-03-18 23:49:27+00:00 → 2026-03-18 23:49:30+00:00  (3 s)
#   Bout 159: 2026-03-18 23:49:36+00:00 → 2026-03-18 23:49:45+00:00  (9 s)
#   Bout 160: 2026-03-18 23:49:48+00:00 → 2026-03-18 23:50:30+00:00  (42 s)
#   Bout 161: 2026-03-18 23:50:33+00:00 → 2026-03-18 23:50:45+00:00  (12 s)
#   Bout 162: 2026-03-18 23:50:54+00:00 → 2026-03-18 23:51:06+00:00  (12 s)
#   Bout 163: 2026-03-18 23:51:15+00:00 → 2026-03-18 23:51:21+00:00  (6 s)
#   Bout 164: 2026-03-18 23:51:24+00:00 → 2026-03-18 23:51:30+00:00  (6 s)
#   Bout 165: 2026-03-18 23:51:33+00:00 → 2026-03-18 23:51:45+00:00  (12 s)
#   Bout 166: 2026-03-18 23:52:18+00:00 → 2026-03-18 23:52:24+00:00  (6 s)
#   Bout 167: 2026-03-18 23:52:33+00:00 → 2026-03-18 23:52:48+00:00  (15 s)
#   Bout 168: 2026-03-18 23:52:54+00:00 → 2026-03-18 23:53:06+00:00  (12 s)
#   Bout 169: 2026-03-18 23:53:09+00:00 → 2026-03-18 23:53:15+00:00  (6 s)
#   Bout 170: 2026-03-18 23:53:21+00:00 → 2026-03-18 23:53:27+00:00  (6 s)
#   Bout 171: 2026-03-18 23:53:30+00:00 → 2026-03-18 23:53:51+00:00  (21 s)
#   Bout 172: 2026-03-18 23:53:54+00:00 → 2026-03-18 23:53:57+00:00  (3 s)
#   Bout 173: 2026-03-18 23:54:00+00:00 → 2026-03-18 23:54:03+00:00  (3 s)
#   Bout 174: 2026-03-18 23:54:06+00:00 → 2026-03-18 23:54:12+00:00  (6 s)
#   Bout 175: 2026-03-18 23:54:15+00:00 → 2026-03-18 23:54:30+00:00  (15 s)
#   Bout 176: 2026-03-18 23:54:33+00:00 → 2026-03-18 23:54:39+00:00  (6 s)
#   Bout 177: 2026-03-18 23:54:45+00:00 → 2026-03-18 23:54:54+00:00  (9 s)
#   Bout 178: 2026-03-18 23:54:57+00:00 → 2026-03-18 23:55:06+00:00  (9 s)
#   Bout 179: 2026-03-18 23:55:09+00:00 → 2026-03-18 23:55:12+00:00  (3 s)
#   Bout 180: 2026-03-18 23:55:15+00:00 → 2026-03-18 23:55:36+00:00  (21 s)
#   Bout 181: 2026-03-18 23:55:39+00:00 → 2026-03-18 23:55:57+00:00  (18 s)
#   Bout 182: 2026-03-18 23:56:03+00:00 → 2026-03-18 23:56:12+00:00  (9 s)
#   Bout 183: 2026-03-18 23:56:15+00:00 → 2026-03-18 23:56:36+00:00  (21 s)
#   Bout 184: 2026-03-18 23:56:39+00:00 → 2026-03-18 23:56:57+00:00  (18 s)
#   Bout 185: 2026-03-18 23:57:09+00:00 → 2026-03-18 23:57:21+00:00  (12 s)
#   Bout 186: 2026-03-18 23:57:24+00:00 → 2026-03-18 23:57:30+00:00  (6 s)
#   Bout 187: 2026-03-18 23:57:36+00:00 → 2026-03-18 23:57:45+00:00  (9 s)
#   Bout 188: 2026-03-18 23:57:51+00:00 → 2026-03-18 23:58:00+00:00  (9 s)
#   Bout 189: 2026-03-18 23:58:03+00:00 → 2026-03-18 23:58:09+00:00  (6 s)
#   Bout 190: 2026-03-18 23:58:12+00:00 → 2026-03-18 23:58:18+00:00  (6 s)
#   Bout 191: 2026-03-18 23:58:21+00:00 → 2026-03-18 23:58:33+00:00  (12 s)
#   Bout 192: 2026-03-18 23:58:36+00:00 → 2026-03-18 23:58:48+00:00  (12 s)
#   Bout 193: 2026-03-18 23:58:51+00:00 → 2026-03-18 23:58:57+00:00  (6 s)
#   Bout 194: 2026-03-18 23:59:06+00:00 → 2026-03-18 23:59:09+00:00  (3 s)
#   Bout 195: 2026-03-18 23:59:24+00:00 → 2026-03-18 23:59:27+00:00  (3 s)
#   Bout 196: 2026-03-18 23:59:30+00:00 → 2026-03-18 23:59:36+00:00  (6 s)
#   Bout 197: 2026-03-18 23:59:39+00:00 → 2026-03-19 00:00:09+00:00  (30 s)
#   Bout 198: 2026-03-19 00:00:12+00:00 → 2026-03-19 00:00:18+00:00  (6 s)
#   Bout 199: 2026-03-19 00:00:21+00:00 → 2026-03-19 00:00:27+00:00  (6 s)
#   Bout 200: 2026-03-19 00:00:30+00:00 → 2026-03-19 00:00:45+00:00  (15 s)
#   Bout 201: 2026-03-19 00:00:48+00:00 → 2026-03-19 00:00:51+00:00  (3 s)
#   Bout 202: 2026-03-19 00:00:54+00:00 → 2026-03-19 00:01:00+00:00  (6 s)
#   Bout 203: 2026-03-19 00:01:03+00:00 → 2026-03-19 00:01:09+00:00  (6 s)
#   Bout 204: 2026-03-19 00:01:12+00:00 → 2026-03-19 00:01:15+00:00  (3 s)
#   Bout 205: 2026-03-19 00:01:18+00:00 → 2026-03-19 00:01:21+00:00  (3 s)
#   Bout 206: 2026-03-19 00:01:24+00:00 → 2026-03-19 00:01:45+00:00  (21 s)
#   Bout 207: 2026-03-19 00:01:51+00:00 → 2026-03-19 00:01:57+00:00  (6 s)
#   Bout 208: 2026-03-19 00:02:03+00:00 → 2026-03-19 00:02:06+00:00  (3 s)
#   Bout 209: 2026-03-19 00:02:12+00:00 → 2026-03-19 00:02:15+00:00  (3 s)
#   Bout 210: 2026-03-19 00:03:06+00:00 → 2026-03-19 00:03:09+00:00  (3 s)
#   Bout 211: 2026-03-19 00:03:12+00:00 → 2026-03-19 00:03:21+00:00  (9 s)

# %%
_COLORS_SKDH = {0: '#ffcccc', 1: '#ccffcc'}

def _min_elapsed(ts_series, t_ref):
    return (ts_series - t_ref).dt.total_seconds() / 60.0


plot_df_mean = df_mean[['Timestamp UTC', 'acc_magnitude']].dropna().copy()
plot_df_mean = plot_df_mean[
    (plot_df_mean['Timestamp UTC'] >= SESSION_START) &
    (plot_df_mean['Timestamp UTC'] <= SESSION_END)
].copy()
t_ref = plot_df_mean['Timestamp UTC'].iloc[0]
plot_df_mean['min_elapsed'] = _min_elapsed(plot_df_mean['Timestamp UTC'], t_ref)

if len(plot_df_mean) > 50_000:
    _stride = max(1, len(plot_df_mean) // 50_000)
    plot_df_mean_ds = plot_df_mean.iloc[::_stride].copy()
else:
    plot_df_mean_ds = plot_df_mean

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(26, 6), sharex=True)

# \u2500\u2500 Top panel: activity labels \u2500\u2500
for _, row in task_intervals.iterrows():
    s = (row['start_time'] - t_ref).total_seconds() / 60.0
    e = (row['end_time']   - t_ref).total_seconds() / 60.0
    ax1.axvspan(s, e, color=TASK_COLORS.get(row['task'], '#cccccc'), alpha=0.35, linewidth=0)
    ax1.text((s + e) / 2, 1.0, row['task'],
             transform=ax1.get_xaxis_transform(),
             ha='center', va='top', fontsize=8, clip_on=True)
ax1.plot(plot_df_mean_ds['min_elapsed'], plot_df_mean_ds['acc_magnitude'], color='black', lw=0.6)
ax1.axhline(0, color='0.5', ls='--', lw=0.6)
ax1.set_ylabel('Mean acc_mag (g)', fontsize=9)
ax1.set_title('Activity labels')
ax1.legend(
    handles=[mpatches.Patch(facecolor=TASK_COLORS[t], edgecolor='none', alpha=0.5, label=t)
             for t in _unique_tasks],
    loc='upper right', fontsize=8, ncol=2,
)

# \u2500\u2500 Bottom panel: SKDH detections \u2500\u2500
skdh_i = skdh_intervals_session.copy()
skdh_i['start_min'] = _min_elapsed(skdh_i['start_time'], t_ref)
skdh_i['end_min']   = _min_elapsed(skdh_i['end_time'],   t_ref)
for _, row in skdh_i.iterrows():
    ax2.axvspan(row['start_min'], row['end_min'],
                color=_COLORS_SKDH[row['prediction']], alpha=0.5, linewidth=0)
ax2.plot(plot_df_mean_ds['min_elapsed'], plot_df_mean_ds['acc_magnitude'], color='black', lw=0.6)
ax2.axhline(0, color='0.5', ls='--', lw=0.6)
ax2.set_ylabel('Mean acc_mag (g)', fontsize=9)
ax2.set_title('SKDH gait classification')
ax2.legend(
    handles=[
        mpatches.Patch(facecolor='#ffcccc', edgecolor='none', alpha=0.5, label='Non-gait'),
        mpatches.Patch(facecolor='#ccffcc', edgecolor='none', alpha=0.5, label='Gait bout'),
    ],
    loc='upper right', fontsize=8,
)
ax2.set_xlabel('Minutes elapsed from session start')

fig.suptitle('Mean acc_magnitude \u2014 2026-03-18 | Activity labels vs SKDH gait detection', fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. AFD-CNN setup

# %%
import importlib
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
tf.logging.set_verbosity(tf.logging.ERROR)

FD_CNN_SRC   = '/home/ubuntu/git/FD-CNN/src'
FD_CNN_MODEL = '/home/ubuntu/git/FD-CNN/model/model.ckpt'

if FD_CNN_SRC not in sys.path:
    sys.path.insert(0, FD_CNN_SRC)

import cnn as cnn_module
importlib.reload(cnn_module)

# AFD-CNN output class mapping (MobiAct v2.0 label set)
FD_CLASS_LIST  = [0, 2, 3, 4, 5, 6, 7, 9]
FD_CLASS_NAMES = {
    0: 'Fall',
    2: 'Walk',
    3: 'Jog',
    4: 'Jump',
    5: 'Up-stairs',
    6: 'Down-stairs',
    7: 'Stand\u2192Sit',
    9: 'Sit\u2192Stand',
}
FD_COLORS = {
    0: '#e84040',  # Fall \u2014 red
    2: '#4a8fd4',  # Walk \u2014 blue
    3: '#56b56e',  # Jog \u2014 green
    4: '#e09c30',  # Jump \u2014 orange
    5: '#9b6bd4',  # Up-stairs \u2014 purple
    6: '#d47bb5',  # Down-stairs \u2014 pink
    7: '#888888',  # Stand\u2192Sit \u2014 grey
    9: '#aaaaaa',  # Sit\u2192Stand \u2014 light grey
}

# Build TensorFlow 1 graph and restore checkpoint
tf.reset_default_graph()
fd_x_ph            = tf.placeholder(tf.float32, [None, 1200], name='fd_input')
fd_logits, fd_keep = cnn_module.fall_net(fd_x_ph)
fd_probs_op        = tf.nn.softmax(fd_logits)

fd_saver = tf.train.Saver()
fd_sess  = tf.Session()
fd_saver.restore(fd_sess, FD_CNN_MODEL)
print('AFD-CNN model restored from', FD_CNN_MODEL)
print('Logits shape:', fd_logits.shape)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776352795.688460   13524 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /home/ubuntu/git/FD-CNN/.venv/lib/python3.12/site-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# AFD-CNN model restored from /home/ubuntu/git/FD-CNN/model/model.ckpt
# Logits shape: (?, 8)
# E0000 00:00:1776352797.074058   13524 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# I0000 00:00:1776352797.077843   13524 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled

# %% [markdown]
# ## 7. Sliding-window scanning over all activity windows
#
# We scan **every activity window** with a 200-sample sliding window at 100 Hz (= 2 s),
# step = 25 samples (= 0.25 s).
#
# Actigraph data is at 64 Hz \u2192 each window is resampled to 100 Hz (AFD-CNN training rate)
# before preprocessing.
#
# The AFD-CNN image format expects **1200 values**: accelerometer in the top half (rows 0\u20139)
# and gyroscope in the bottom half (rows 10\u201319). Since the Actigraph records only
# accelerometer data, the **gyroscope half is filled by copying the accelerometer data**.

# %%
# \u2500\u2500 Resampling & preprocessing constants \u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500
FD_FS_IN     = FS_ACTI   # 64 Hz  \u2014 Actigraph native rate
FD_FS_TRAIN  = 100       # Hz     \u2014 AFD-CNN training rate
FD_WIN_LEN   = 200       # samples at 100 Hz = 2 s
FD_STEP      = 25        # samples at 100 Hz = 0.25 s


def resample_bout(arr_g, fs_in, fs_out):
    """Polyphase resample (N, 3) g-unit array from fs_in to fs_out."""
    g = gcd(int(fs_in), int(fs_out))
    return resample_poly(arr_g, int(fs_out) // g, int(fs_in) // g, axis=0).astype(np.float32)


def g_to_uint8(arr_g):
    """
    Convert g-unit accelerometer data to [0, 255] matching AFD-CNN training preprocessing.

    Training formula (transform.py): (sensor_ms2 + data_move) * data_scale
    data_move=20, data_scale=6  \u2192  maps \u00b120 m/s\u00b2 \u2248 \u00b12 g to [0, 240].
    Actigraph data is in g \u2192 multiply by 9.81 to get m/s\u00b2 first.
    """
    return np.clip((arr_g * 9.81 + 20.0) * 6.0, 0.0, 255.0).astype(np.float32)


def extract_windows_from_segment(accel_64hz, timestamps_64hz, win_len, step, fs_in, fs_out):
    """
    Resample a (N, 3) segment from fs_in to fs_out, then scan with a sliding window.

    Each window: (win_len, 3) accelerometer \u2192 g_to_uint8 \u2192 flatten to (600,).
    The accelerometer half is then copied as a gyroscope proxy to produce the full
    (1200,) input expected by the AFD-CNN (top half = acc, bottom half = gyro proxy).

    Returns
    -------
    windows : (N_windows, 1200) float32 in [0, 255]
    meta    : list of dicts with 'win_idx', 'start_dt', 'end_dt'
    """
    if len(accel_64hz) == 0:
        return np.empty((0, 1200), dtype=np.float32), []

    scale = fs_out / fs_in
    arr_resampled = resample_bout(accel_64hz, fs_in, fs_out)  # (N_resamp, 3)
    arr_uint8     = g_to_uint8(arr_resampled)                  # (N_resamp, 3)

    windows, meta = [], []
    n_resamp = len(arr_resampled)

    for w_idx, off in enumerate(range(0, n_resamp - win_len + 1, step)):
        chunk = arr_uint8[off: off + win_len]          # (200, 3) \u2014 accelerometer
        flat  = chunk.flatten()                         # (600,)   \u2014 acc flattened
        windows.append(np.concatenate([flat, flat]))   # (1200,)  \u2014 acc + acc copy as gyro proxy

        # Map resampled sample indices back to original 64 Hz timestamps
        s_orig = min(int(off / scale),            len(timestamps_64hz) - 1)
        e_orig = min(int((off + win_len) / scale), len(timestamps_64hz) - 1)
        meta.append(dict(
            win_idx=w_idx,
            start_dt=timestamps_64hz[s_orig],
            end_dt=timestamps_64hz[e_orig],
        ))

    return np.array(windows, dtype=np.float32), meta


print(f'Sliding-window parameters:')
print(f'  Native Actigraph rate : {FD_FS_IN} Hz')
print(f'  Resample target rate  : {FD_FS_TRAIN} Hz')
print(f'  Window length         : {FD_WIN_LEN} samples @ {FD_FS_TRAIN} Hz = {FD_WIN_LEN/FD_FS_TRAIN:.2f} s')
print(f'  Step                  : {FD_STEP} samples @ {FD_FS_TRAIN} Hz = {FD_STEP/FD_FS_TRAIN:.3f} s')
print(f'  Image layout          : acc (rows 0\u20139) + acc copy as gyro proxy (rows 10\u201319)')
# Out:
# Sliding-window parameters:
#   Native Actigraph rate : 64 Hz
#   Resample target rate  : 100 Hz
#   Window length         : 200 samples @ 100 Hz = 2.00 s
#   Step                  : 25 samples @ 100 Hz = 0.250 s
#   Image layout          : acc (rows 0–9) + acc copy as gyro proxy (rows 10–19)

# %%
# Scan ALL activity windows with AFD-CNN
# We use the Right Wrist (RW) X/Y/Z signal as the reference for the CNN,
# consistent with the wrist-worn deployment context.

all_windows  = []   # (1200,) flattened windows
all_meta     = []   # list of dicts with task, window info

for (win_str, task) in zip(classification_windows_2026_03_18, classification_tasks_2026_03_18):
    t0, tf = resolve_time_window(win_str)

    # Slice RW signal for this activity window
    seg = df_RW[
        (df_RW['Timestamp UTC'] >= t0) & (df_RW['Timestamp UTC'] <= tf)
    ][['Timestamp UTC', 'x', 'y', 'z']].dropna().copy()

    if seg.empty:
        print(f'  [{task}] \u2014 no data in window, skipping')
        continue

    accel_seg = seg[['x', 'y', 'z']].to_numpy(dtype=np.float32)
    ts_seg    = seg['Timestamp UTC'].to_numpy()

    wins, meta = extract_windows_from_segment(
        accel_seg, ts_seg,
        win_len=FD_WIN_LEN, step=FD_STEP,
        fs_in=FD_FS_IN, fs_out=FD_FS_TRAIN,
    )

    dur_s = (tf - t0).total_seconds()
    print(f'  [{task}]  {len(seg):,} samples ({dur_s:.0f} s)  \u2192  {len(wins)} windows')

    for m in meta:
        m['task'] = task
        m['win_start_tag'] = t0
        m['win_end_tag']   = tf

    all_windows.append(wins)
    all_meta.extend(meta)

if all_windows:
    fd_windows = np.vstack(all_windows)
else:
    fd_windows = np.empty((0, 1200), dtype=np.float32)

print(f'\nTotal windows across all activity windows: {len(fd_windows)}')
print(f'Input tensor shape : {fd_windows.shape}')
if len(fd_windows):
    print(f'Value range        : [{fd_windows.min():.1f}, {fd_windows.max():.1f}]')
# Out:
#   [Evening walk]  146,305 samples (2400 s)  →  9137 windows
#   [Bicycle]  115,201 samples (1800 s)  →  7193 windows
#   [Daily walking]  268,801 samples (4200 s)  →  16793 windows
#
# Total windows across all activity windows: 33123
# Input tensor shape : (33123, 1200)
# Value range        : [0.0, 255.0]

# %%
# Run all windows through AFD-CNN (single forward pass in batches for memory safety)
BATCH_SIZE = 512

if len(fd_windows) == 0:
    print('No windows to classify.')
else:
    fd_probs_list = []
    for start in range(0, len(fd_windows), BATCH_SIZE):
        batch = fd_windows[start: start + BATCH_SIZE]
        probs = fd_sess.run(fd_probs_op, feed_dict={fd_x_ph: batch, fd_keep: 1.0})
        fd_probs_list.append(probs)

    fd_probs       = np.vstack(fd_probs_list)                          # (N, 8)
    fd_pred_idx    = np.argmax(fd_probs, axis=1)
    fd_pred_labels = [FD_CLASS_LIST[i]   for i in fd_pred_idx]
    fd_pred_names  = [FD_CLASS_NAMES[l]  for l in fd_pred_labels]
    fd_fall_probs  = fd_probs[:, FD_CLASS_LIST.index(0)]               # P(Fall)

    fd_results = pd.DataFrame(all_meta)
    fd_results['pred_label'] = fd_pred_labels
    fd_results['pred_name']  = fd_pred_names
    fd_results['fall_prob']  = fd_fall_probs
    fd_results['max_prob']   = fd_probs.max(axis=1)

    # Convert numpy datetime64 timestamps to pd.Timestamp
    fd_results['start_dt'] = pd.to_datetime(fd_results['start_dt'], utc=True)
    fd_results['end_dt']   = pd.to_datetime(fd_results['end_dt'],   utc=True)

    n_fall = (fd_results['pred_label'] == 0).sum()
    print(f'=== AFD-CNN results: {len(fd_results)} windows total ===')
    print(f'  Fall alerts : {n_fall} / {len(fd_results)} ({n_fall/len(fd_results):.1%})')
    print()
    print('Predicted class distribution across all activity windows:')
    print(fd_results['pred_name'].value_counts().to_string())
# Out:
# === AFD-CNN results: 33123 windows total ===
#   Fall alerts : 5609 / 33123 (16.9%)
#
# Predicted class distribution across all activity windows:
# pred_name
# Down-stairs    20289
# Jog             7074
# Fall            5609
# Up-stairs        104
# Sit→Stand         26
# Walk              20
# Jump               1

# %%
# \u2500\u2500 Best-detected window per predicted class (20\u00d720 RGB image, one per class) \u2500\u2500
# For each AFD-CNN class, find the window with the highest softmax probability
# and display it as a 20\u00d720 RGB image.

def to_image_acti(window_values):
    """Reshape 1200 flattened sensor values to a displayable 20\u00d720\u00d73 image."""
    img = np.array(window_values, dtype=np.float32).reshape(20, 20, 3)
    return img / 255.0   # scale to [0, 1] for imshow

n_cl = len(FD_CLASS_LIST)
fig, axes = plt.subplots(1, n_cl, figsize=(2.2 * n_cl, 3.2))

for ax, label in zip(axes, FD_CLASS_LIST):
    cls_idx   = FD_CLASS_LIST.index(label)
    best_idx  = int(np.argmax(fd_probs[:, cls_idx]))
    best_prob = fd_probs[best_idx, cls_idx]
    best_task = fd_results.iloc[best_idx]['task']

    img = to_image_acti(fd_windows[best_idx])
    ax.imshow(img)

    name  = FD_CLASS_NAMES[label]
    color = 'red' if label == 0 else 'black'
    ax.set_title(f'{name} p={best_prob:.3f} ({best_task})',
                 fontsize=7.5, color=color, fontweight='bold')
    ax.axis('off')
    if label == 0:
        for spine in ax.spines.values():
            spine.set_edgecolor('red')
            spine.set_linewidth(2)

fig.suptitle(
    'Most confident window per predicted class \u2014 2026-03-18 activity windows\n'
    '20\u00d720 px image = one 2 s motion window  (R/G/B = sensor X/Y/Z axes)',
    fontsize=11, fontweight='bold',
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Results \u2014 per-activity summary

# %%
# Per-activity prediction breakdown
if len(fd_results) > 0:
    task_summary = (
        fd_results
        .groupby('task')
        .agg(
            n_windows=('pred_name', 'count'),
            fall_alerts=('pred_label', lambda x: (x == 0).sum()),
            mean_fall_prob=('fall_prob', 'mean'),
            max_fall_prob=('fall_prob', 'max'),
            top_class=('pred_name', lambda x: x.mode()[0]),
        )
        .reset_index()
    )
    task_summary['fall_alert_rate'] = task_summary['fall_alerts'] / task_summary['n_windows']

    # Preserve original activity order
    task_order = list(dict.fromkeys(classification_tasks_2026_03_18))
    task_summary['_order'] = task_summary['task'].map({t: i for i, t in enumerate(task_order)})
    task_summary = task_summary.sort_values('_order').drop(columns='_order')

    print('=== Per-activity AFD-CNN summary ===')
    print(task_summary.to_string(index=False, float_format='{:.3f}'.format))
# Out:
# === Per-activity AFD-CNN summary ===
#          task  n_windows  fall_alerts  mean_fall_prob  max_fall_prob   top_class  fall_alert_rate
#  Evening walk       9137         2481           0.170          0.577 Down-stairs            0.272
#       Bicycle       7193         2111           0.160          0.571 Down-stairs            0.293
# Daily walking      16793         1017           0.145          0.595 Down-stairs            0.061

# %% [markdown]
# ## 9. Visualisation \u2014 P(Fall) over time per activity

# %%
# Full-session timeline: RW acc_magnitude with AFD-CNN window shading
if len(fd_results) > 0:
    plot_rw = df_RW[['Timestamp UTC', 'acc_magnitude']].dropna().copy()
    plot_rw = plot_rw[
        (plot_rw['Timestamp UTC'] >= SESSION_START) &
        (plot_rw['Timestamp UTC'] <= SESSION_END)
    ].copy()
    t_ref_rw = plot_rw['Timestamp UTC'].iloc[0]
    plot_rw['min_elapsed'] = (plot_rw['Timestamp UTC'] - t_ref_rw).dt.total_seconds() / 60.0

    if len(plot_rw) > 80_000:
        plot_rw = plot_rw.iloc[::max(1, len(plot_rw) // 80_000)].copy()

    fig, ax = plt.subplots(figsize=(28, 4))
    ax.plot(plot_rw['min_elapsed'], plot_rw['acc_magnitude'], color='black', lw=0.5, alpha=0.7)

    for _, row in fd_results.iterrows():
        s = (row['start_dt'] - t_ref_rw).total_seconds() / 60.0
        e = (row['end_dt']   - t_ref_rw).total_seconds() / 60.0
        ax.axvspan(s, e, color=FD_COLORS.get(row['pred_label'], '#cccccc'), alpha=0.18, linewidth=0)

    # Mark activity window boundaries
    for _, row in task_intervals.iterrows():
        s = (row['start_time'] - t_ref_rw).total_seconds() / 60.0
        e = (row['end_time']   - t_ref_rw).total_seconds() / 60.0
        ax.axvline(s, color='0.4', ls=':', lw=1.0)
        ax.axvline(e, color='0.4', ls=':', lw=1.0)
        ax.text((s + e) / 2, 1.01, row['task'],
                transform=ax.get_xaxis_transform(),
                ha='center', va='bottom', fontsize=9)

    ax.axhline(0, color='0.5', ls='--', lw=0.5)
    ax.set_xlabel('Minutes elapsed from session start')
    ax.set_ylabel('RW acc_magnitude (g)')
    ax.set_title(
        f'AFD-CNN predictions \u2014 2026-03-18 (RW signal)\n'
        f'Window = {FD_WIN_LEN} samples @ {FD_FS_TRAIN} Hz ({FD_WIN_LEN/FD_FS_TRAIN:.1f} s), '
        f'step = {FD_STEP/FD_FS_TRAIN:.2f} s',
        fontsize=11,
    )
    legend_patches = [
        mpatches.Patch(color=FD_COLORS[l], alpha=0.5, label=FD_CLASS_NAMES[l])
        for l in FD_CLASS_LIST
    ]
    ax.legend(handles=legend_patches, fontsize=8, loc='upper right', ncol=4, framealpha=0.8)
    plt.tight_layout()
    plt.show()

# %%
# Per-activity zoom: one figure per activity window showing RW signal + AFD-CNN predictions
if len(fd_results) > 0:
    for (win_str, task) in zip(classification_windows_2026_03_18, classification_tasks_2026_03_18):
        t0_z, tf_z = resolve_time_window(win_str)

        task_wins = fd_results[
            (fd_results['task'] == task) &
            (fd_results['start_dt'] >= t0_z) &
            (fd_results['end_dt']   <= tf_z)
        ].copy()
        if task_wins.empty:
            continue

        seg_rw = df_RW[
            (df_RW['Timestamp UTC'] >= t0_z) &
            (df_RW['Timestamp UTC'] <= tf_z)
        ][['Timestamp UTC', 'acc_magnitude']].dropna().copy()
        if seg_rw.empty:
            continue

        t_ref_z = seg_rw['Timestamp UTC'].iloc[0]
        seg_rw['sec_elapsed'] = (seg_rw['Timestamp UTC'] - t_ref_z).dt.total_seconds()
        if len(seg_rw) > 20_000:
            seg_rw = seg_rw.iloc[::max(1, len(seg_rw) // 20_000)].copy()

        fig, (ax_sig, ax_fall) = plt.subplots(
            2, 1, figsize=(14, 5),
            gridspec_kw={'height_ratios': [3, 1]},
        )

        # \u2500\u2500 Signal panel \u2500\u2500
        ax_sig.plot(seg_rw['sec_elapsed'], seg_rw['acc_magnitude'], color='black', lw=0.7)
        for _, row in task_wins.iterrows():
            s = (row['start_dt'] - t_ref_z).total_seconds()
            e = (row['end_dt']   - t_ref_z).total_seconds()
            ax_sig.axvspan(s, e,
                           color=FD_COLORS.get(row['pred_label'], '#cccccc'),
                           alpha=0.30, linewidth=0)
        ax_sig.axhline(0, color='0.5', ls='--', lw=0.5)
        ax_sig.set_ylabel('RW acc_mag (g)', fontsize=9)
        ax_sig.set_title(
            f'Activity: {task}  |  {win_str[0]} \u2192 {win_str[1]}  '
            f'({len(task_wins)} windows)',
            fontsize=10,
        )
        ax_sig.legend(
            handles=[mpatches.Patch(color=FD_COLORS[l], alpha=0.5, label=FD_CLASS_NAMES[l])
                     for l in FD_CLASS_LIST],
            fontsize=7, loc='upper right', ncol=4, framealpha=0.8,
        )

        # \u2500\u2500 P(Fall) bar panel \u2500\u2500
        x_sec = [(row['start_dt'] - t_ref_z).total_seconds() for _, row in task_wins.iterrows()]
        colors_bar = ['#e84040' if p >= 0.3 else '#4a8fd4' for p in task_wins['fall_prob']]
        ax_fall.bar(x_sec, task_wins['fall_prob'], width=FD_WIN_LEN / FD_FS_TRAIN * 0.9,
                    color=colors_bar, edgecolor='none', align='edge')
        ax_fall.axhline(0.3, color='red', ls='--', lw=0.8, label='P(Fall)=0.3 threshold')
        ax_fall.set_ylim(0, 1.05)
        ax_fall.set_ylabel('P(Fall)', fontsize=9)
        ax_fall.set_xlabel('Seconds elapsed')
        ax_fall.legend(fontsize=8, loc='upper right')

        # Sync x-axis limits
        x_min = seg_rw['sec_elapsed'].iloc[0]
        x_max = seg_rw['sec_elapsed'].iloc[-1]
        ax_sig.set_xlim(x_min, x_max)
        ax_fall.set_xlim(x_min, x_max)

        fig.suptitle(f'AFD-CNN \u2014 {task}', fontsize=12, fontweight='bold')
        plt.tight_layout()
        plt.show()

# %%
# Stacked bar: predicted class distribution per activity
if len(fd_results) > 0:
    _class_order = [FD_CLASS_NAMES[l] for l in FD_CLASS_LIST]
    _counts = (
        fd_results
        .groupby(['task', 'pred_name'])
        .size()
        .unstack(fill_value=0)
        .reindex(columns=_class_order, fill_value=0)
    )
    # Preserve activity order
    task_order = list(dict.fromkeys(classification_tasks_2026_03_18))
    _counts = _counts.reindex([t for t in task_order if t in _counts.index])

    _pct = _counts.div(_counts.sum(axis=1), axis=0) * 100

    _class_colors = [FD_COLORS[l] for l in FD_CLASS_LIST]

    fig, ax = plt.subplots(figsize=(10, 5))
    _pct.plot(kind='bar', stacked=True, ax=ax, color=_class_colors,
              edgecolor='white', linewidth=0.3)
    ax.set_ylabel('% of windows', fontsize=10)
    ax.set_xlabel('')
    ax.set_xticklabels(_pct.index, rotation=20, ha='right', fontsize=10)
    ax.set_ylim(0, 105)
    ax.legend(title='Predicted class', fontsize=8, loc='upper right', ncol=2)
    ax.set_title('AFD-CNN predicted class distribution per activity \u2014 2026-03-18',
                 fontsize=12, fontweight='bold')
    plt.tight_layout()
    plt.show()

    print('\n=== Predicted class distribution per activity (window counts) ===')
    print(_counts.to_string())
# Out:
# === Predicted class distribution per activity (window counts) ===
# pred_name      Fall  Walk   Jog  Jump  Up-stairs  Down-stairs  Stand→Sit  Sit→Stand
# task
# Evening walk   2481     7  2216     1         25         4403          0          4
# Bicycle        2111     7   513     0         34         4521          0          7
# Daily walking  1017     6  4345     0         45        11365          0         15

# %% [markdown]
# ## 10. SKDH walking bouts vs AFD-CNN predictions

# %%
# Cross-reference: for each SKDH-detected gait bout, show AFD-CNN window predictions
if n_bouts > 0 and len(fd_results) > 0:
    gait_starts_utc = pd.to_datetime(skdh_result_session['Gait Bout Start'], unit='s', utc=True)
    gait_stops_utc  = pd.to_datetime(skdh_result_session['Gait Bout Stop'],  unit='s', utc=True)

    print('=== AFD-CNN predictions inside SKDH gait bouts ===')
    for i, (gs, ge) in enumerate(zip(gait_starts_utc, gait_stops_utc)):
        dur = (ge - gs).total_seconds()

        # Find windows whose start falls inside this bout
        in_bout = fd_results[
            (fd_results['start_dt'] >= gs) & (fd_results['start_dt'] <= ge)
        ]
        if in_bout.empty:
            print(f'  Bout {i+1} ({dur:.0f} s): no AFD-CNN windows matched')
            continue

        n_fall_bout = (in_bout['pred_label'] == 0).sum()
        top_task    = in_bout['task'].mode()[0] if 'task' in in_bout.columns else '?'
        print(f'  Bout {i+1} ({dur:.0f} s | {gs.strftime("%H:%M:%S")}\u2013{ge.strftime("%H:%M:%S")}): '
              f'{len(in_bout)} windows  |  '
              f'Fall alerts: {n_fall_bout}  |  '
              f'Top class: {in_bout["pred_name"].mode()[0]}  |  '
              f'Activity tag: {top_task}')
else:
    print('No SKDH gait bouts detected or no AFD-CNN results available.')
# Out:
# === AFD-CNN predictions inside SKDH gait bouts ===
#   Bout 1 (3 s | 20:30:09–20:30:12): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Evening walk
#   Bout 2 (3 s | 20:31:12–20:31:15): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Evening walk
#   Bout 3 (24 s | 20:31:30–20:31:54): 97 windows  |  Fall alerts: 1  |  Top class: Jog  |  Activity tag: Evening walk
#   Bout 4 (18 s | 20:32:03–20:32:21): 73 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Evening walk
#   Bout 5 (3 s | 20:32:24–20:32:27): 13 windows  |  Fall alerts: 2  |  Top class: Jog  |  Activity tag: Evening walk
#   Bout 6 (69 s | 20:32:36–20:33:45): 277 windows  |  Fall alerts: 3  |  Top class: Jog  |  Activity tag: Evening walk
#   Bout 7 (6 s | 20:33:54–20:34:00): 25 windows  |  Fall alerts: 1  |  Top class: Down-stairs  |  Activity tag: Evening walk
#   Bout 8 (90 s | 20:34:03–20:35:33): 361 windows  |  Fall alerts: 9  |  Top class: Jog  |  Activity tag: Evening walk
#   Bout 9 (3 s | 20:35:36–20:35:39): 13 windows  |  Fall alerts: 1  |  Top class: Jog  |  Activity tag: Evening walk
#   Bout 10 (84 s | 20:35:48–20:37:12): 337 windows  |  Fall alerts: 4  |  Top class: Jog  |  Activity tag: Evening walk
#   Bout 11 (6 s | 20:37:21–20:37:27): 25 windows  |  Fall alerts: 1  |  Top class: Down-stairs  |  Activity tag: Evening walk
#   Bout 12 (48 s | 20:37:30–20:38:18): 193 windows  |  Fall alerts: 7  |  Top class: Jog  |  Activity tag: Evening walk
#   Bout 13 (21 s | 20:38:24–20:38:45): 85 windows  |  Fall alerts: 2  |  Top class: Jog  |  Activity tag: Evening walk
#   Bout 14 (9 s | 20:38:51–20:39:00): 37 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Evening walk
#   Bout 15 (60 s | 20:39:03–20:40:03): 241 windows  |  Fall alerts: 3  |  Top class: Jog  |  Activity tag: Evening walk
#   Bout 16 (300 s | 20:40:06–20:45:06): 1201 windows  |  Fall alerts: 23  |  Top class: Jog  |  Activity tag: Evening walk
#   Bout 17 (3 s | 20:45:12–20:45:15): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Evening walk
#   Bout 18 (3 s | 20:45:36–20:45:39): 13 windows  |  Fall alerts: 3  |  Top class: Down-stairs  |  Activity tag: Evening walk
#   Bout 19 (3 s | 20:46:03–20:46:06): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Evening walk
#   Bout 20 (3 s | 21:11:33–21:11:36): 13 windows  |  Fall alerts: 13  |  Top class: Fall  |  Activity tag: Bicycle
#   Bout 21 (3 s | 21:14:54–21:14:57): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Bicycle
#   Bout 22 (3 s | 21:15:42–21:15:45): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Bicycle
#   Bout 23 (3 s | 21:16:33–21:16:36): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Bicycle
#   Bout 24 (3 s | 21:17:48–21:17:51): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Bicycle
#   Bout 25 (3 s | 21:22:00–21:22:03): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Bicycle
#   Bout 26 (3 s | 21:22:27–21:22:30): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Bicycle
#   Bout 27 (3 s | 21:25:36–21:25:39): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Bicycle
#   Bout 28 (3 s | 21:30:06–21:30:09): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Bicycle
#   Bout 29 (3 s | 23:15:09–23:15:12): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 30 (9 s | 23:15:18–23:15:27): 37 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 31 (3 s | 23:15:42–23:15:45): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 32 (6 s | 23:15:48–23:15:54): 25 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 33 (12 s | 23:16:09–23:16:21): 49 windows  |  Fall alerts: 2  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 34 (6 s | 23:16:27–23:16:33): 25 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 35 (9 s | 23:16:36–23:16:45): 37 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 36 (12 s | 23:16:48–23:17:00): 49 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 37 (9 s | 23:17:06–23:17:15): 37 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 38 (6 s | 23:17:18–23:17:24): 25 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 39 (3 s | 23:17:27–23:17:30): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 40 (3 s | 23:17:39–23:17:42): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 41 (12 s | 23:17:45–23:17:57): 49 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 42 (3 s | 23:18:03–23:18:06): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 43 (3 s | 23:18:09–23:18:12): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 44 (6 s | 23:18:33–23:18:39): 25 windows  |  Fall alerts: 1  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 45 (6 s | 23:18:42–23:18:48): 25 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 46 (3 s | 23:18:51–23:18:54): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 47 (9 s | 23:19:03–23:19:12): 37 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 48 (18 s | 23:19:15–23:19:33): 73 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 49 (6 s | 23:19:36–23:19:42): 25 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 50 (3 s | 23:19:45–23:19:48): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 51 (6 s | 23:19:57–23:20:03): 25 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 52 (3 s | 23:20:09–23:20:12): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 53 (3 s | 23:20:30–23:20:33): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 54 (3 s | 23:20:57–23:21:00): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 55 (3 s | 23:21:21–23:21:24): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 56 (3 s | 23:21:30–23:21:33): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 57 (3 s | 23:21:57–23:22:00): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 58 (9 s | 23:22:03–23:22:12): 37 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 59 (9 s | 23:22:15–23:22:24): 37 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 60 (6 s | 23:22:27–23:22:33): 25 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 61 (3 s | 23:22:39–23:22:42): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 62 (9 s | 23:22:45–23:22:54): 37 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 63 (3 s | 23:23:09–23:23:12): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 64 (6 s | 23:23:27–23:23:33): 25 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 65 (9 s | 23:23:36–23:23:45): 37 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 66 (9 s | 23:23:57–23:24:06): 37 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 67 (45 s | 23:24:09–23:24:54): 181 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 68 (6 s | 23:25:15–23:25:21): 25 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 69 (33 s | 23:25:24–23:25:57): 133 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 70 (51 s | 23:26:00–23:26:51): 205 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 71 (24 s | 23:27:30–23:27:54): 97 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 72 (6 s | 23:28:00–23:28:06): 25 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 73 (39 s | 23:28:15–23:28:54): 157 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 74 (6 s | 23:28:57–23:29:03): 25 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 75 (27 s | 23:29:09–23:29:36): 109 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 76 (15 s | 23:29:39–23:29:54): 61 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 77 (6 s | 23:29:57–23:30:03): 25 windows  |  Fall alerts: 1  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 78 (3 s | 23:30:12–23:30:15): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 79 (6 s | 23:30:24–23:30:30): 25 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 80 (3 s | 23:30:57–23:31:00): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 81 (6 s | 23:31:03–23:31:09): 25 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 82 (9 s | 23:31:12–23:31:21): 37 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 83 (12 s | 23:31:27–23:31:39): 49 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 84 (3 s | 23:31:57–23:32:00): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 85 (6 s | 23:32:06–23:32:12): 25 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 86 (3 s | 23:32:24–23:32:27): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 87 (6 s | 23:33:03–23:33:09): 25 windows  |  Fall alerts: 2  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 88 (6 s | 23:33:12–23:33:18): 25 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 89 (6 s | 23:33:21–23:33:27): 25 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 90 (3 s | 23:33:30–23:33:33): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 91 (3 s | 23:33:36–23:33:39): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 92 (3 s | 23:33:42–23:33:45): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 93 (6 s | 23:33:51–23:33:57): 25 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 94 (3 s | 23:34:12–23:34:15): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 95 (6 s | 23:34:21–23:34:27): 25 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 96 (3 s | 23:34:33–23:34:36): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 97 (3 s | 23:34:42–23:34:45): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 98 (6 s | 23:34:48–23:34:54): 25 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 99 (6 s | 23:35:06–23:35:12): 25 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 100 (3 s | 23:35:15–23:35:18): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 101 (9 s | 23:35:21–23:35:30): 37 windows  |  Fall alerts: 1  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 102 (3 s | 23:35:45–23:35:48): 13 windows  |  Fall alerts: 1  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 103 (3 s | 23:36:06–23:36:09): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 104 (3 s | 23:36:33–23:36:36): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 105 (3 s | 23:36:39–23:36:42): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 106 (9 s | 23:36:48–23:36:57): 37 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 107 (6 s | 23:37:00–23:37:06): 25 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 108 (3 s | 23:37:09–23:37:12): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 109 (3 s | 23:37:15–23:37:18): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 110 (18 s | 23:38:42–23:39:00): 73 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 111 (3 s | 23:39:03–23:39:06): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 112 (12 s | 23:39:09–23:39:21): 49 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 113 (12 s | 23:39:27–23:39:39): 49 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 114 (12 s | 23:39:48–23:40:00): 49 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 115 (3 s | 23:40:03–23:40:06): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 116 (3 s | 23:40:12–23:40:15): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 117 (6 s | 23:40:21–23:40:27): 25 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 118 (6 s | 23:40:30–23:40:36): 25 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 119 (3 s | 23:40:39–23:40:42): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 120 (6 s | 23:40:45–23:40:51): 25 windows  |  Fall alerts: 2  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 121 (3 s | 23:40:54–23:40:57): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 122 (3 s | 23:41:09–23:41:12): 13 windows  |  Fall alerts: 1  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 123 (9 s | 23:41:18–23:41:27): 37 windows  |  Fall alerts: 2  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 124 (3 s | 23:41:33–23:41:36): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 125 (27 s | 23:41:42–23:42:09): 109 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 126 (3 s | 23:42:12–23:42:15): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 127 (3 s | 23:42:21–23:42:24): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 128 (3 s | 23:42:30–23:42:33): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 129 (24 s | 23:42:36–23:43:00): 97 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 130 (6 s | 23:43:06–23:43:12): 25 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 131 (3 s | 23:43:15–23:43:18): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 132 (3 s | 23:43:24–23:43:27): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 133 (3 s | 23:43:36–23:43:39): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 134 (9 s | 23:43:42–23:43:51): 37 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 135 (3 s | 23:44:09–23:44:12): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 136 (9 s | 23:44:15–23:44:24): 37 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 137 (3 s | 23:44:30–23:44:33): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 138 (3 s | 23:44:36–23:44:39): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 139 (6 s | 23:44:42–23:44:48): 25 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 140 (3 s | 23:44:51–23:44:54): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 141 (3 s | 23:45:00–23:45:03): 13 windows  |  Fall alerts: 1  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 142 (3 s | 23:45:09–23:45:12): 13 windows  |  Fall alerts: 1  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 143 (3 s | 23:45:18–23:45:21): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 144 (21 s | 23:45:30–23:45:51): 85 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 145 (3 s | 23:46:03–23:46:06): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 146 (3 s | 23:46:09–23:46:12): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 147 (9 s | 23:46:15–23:46:24): 37 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 148 (6 s | 23:46:27–23:46:33): 25 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 149 (9 s | 23:46:36–23:46:45): 37 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 150 (6 s | 23:46:48–23:46:54): 25 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 151 (18 s | 23:46:57–23:47:15): 73 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 152 (15 s | 23:47:21–23:47:36): 61 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 153 (3 s | 23:47:39–23:47:42): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 154 (42 s | 23:47:48–23:48:30): 169 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 155 (24 s | 23:48:33–23:48:57): 97 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 156 (3 s | 23:49:03–23:49:06): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 157 (6 s | 23:49:12–23:49:18): 25 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 158 (3 s | 23:49:27–23:49:30): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 159 (9 s | 23:49:36–23:49:45): 37 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 160 (42 s | 23:49:48–23:50:30): 169 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 161 (12 s | 23:50:33–23:50:45): 49 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 162 (12 s | 23:50:54–23:51:06): 49 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 163 (6 s | 23:51:15–23:51:21): 25 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 164 (6 s | 23:51:24–23:51:30): 25 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 165 (12 s | 23:51:33–23:51:45): 49 windows  |  Fall alerts: 1  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 166 (6 s | 23:52:18–23:52:24): 25 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 167 (15 s | 23:52:33–23:52:48): 61 windows  |  Fall alerts: 2  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 168 (12 s | 23:52:54–23:53:06): 49 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 169 (6 s | 23:53:09–23:53:15): 25 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 170 (6 s | 23:53:21–23:53:27): 25 windows  |  Fall alerts: 1  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 171 (21 s | 23:53:30–23:53:51): 85 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 172 (3 s | 23:53:54–23:53:57): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 173 (3 s | 23:54:00–23:54:03): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 174 (6 s | 23:54:06–23:54:12): 25 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 175 (15 s | 23:54:15–23:54:30): 61 windows  |  Fall alerts: 1  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 176 (6 s | 23:54:33–23:54:39): 25 windows  |  Fall alerts: 1  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 177 (9 s | 23:54:45–23:54:54): 37 windows  |  Fall alerts: 1  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 178 (9 s | 23:54:57–23:55:06): 37 windows  |  Fall alerts: 1  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 179 (3 s | 23:55:09–23:55:12): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 180 (21 s | 23:55:15–23:55:36): 85 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 181 (18 s | 23:55:39–23:55:57): 73 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 182 (9 s | 23:56:03–23:56:12): 37 windows  |  Fall alerts: 3  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 183 (21 s | 23:56:15–23:56:36): 85 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 184 (18 s | 23:56:39–23:56:57): 73 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 185 (12 s | 23:57:09–23:57:21): 49 windows  |  Fall alerts: 1  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 186 (6 s | 23:57:24–23:57:30): 25 windows  |  Fall alerts: 1  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 187 (9 s | 23:57:36–23:57:45): 37 windows  |  Fall alerts: 1  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 188 (9 s | 23:57:51–23:58:00): 37 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 189 (6 s | 23:58:03–23:58:09): 25 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 190 (6 s | 23:58:12–23:58:18): 25 windows  |  Fall alerts: 1  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 191 (12 s | 23:58:21–23:58:33): 49 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 192 (12 s | 23:58:36–23:58:48): 49 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 193 (6 s | 23:58:51–23:58:57): 25 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 194 (3 s | 23:59:06–23:59:09): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 195 (3 s | 23:59:24–23:59:27): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 196 (6 s | 23:59:30–23:59:36): 25 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 197 (30 s | 23:59:39–00:00:09): 121 windows  |  Fall alerts: 1  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 198 (6 s | 00:00:12–00:00:18): 25 windows  |  Fall alerts: 1  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 199 (6 s | 00:00:21–00:00:27): 25 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 200 (15 s | 00:00:30–00:00:45): 61 windows  |  Fall alerts: 2  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 201 (3 s | 00:00:48–00:00:51): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 202 (6 s | 00:00:54–00:01:00): 25 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 203 (6 s | 00:01:03–00:01:09): 25 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 204 (3 s | 00:01:12–00:01:15): 13 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 205 (3 s | 00:01:18–00:01:21): 13 windows  |  Fall alerts: 1  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 206 (21 s | 00:01:24–00:01:45): 85 windows  |  Fall alerts: 0  |  Top class: Jog  |  Activity tag: Daily walking
#   Bout 207 (6 s | 00:01:51–00:01:57): 25 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 208 (3 s | 00:02:03–00:02:06): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 209 (3 s | 00:02:12–00:02:15): 13 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 210 (3 s | 00:03:06–00:03:09): 13 windows  |  Fall alerts: 1  |  Top class: Down-stairs  |  Activity tag: Daily walking
#   Bout 211 (9 s | 00:03:12–00:03:21): 37 windows  |  Fall alerts: 0  |  Top class: Down-stairs  |  Activity tag: Daily walking

# %%
# Close TF session
fd_sess.close()
print('TF session closed.')
# Out:
# TF session closed.
